# %%
import pandas as pd

# %%
AAPL = pd.read_csv('aapl.csv', index_col=0, parse_dates=True)

# %%
AAPL
# Out:
#               Open    High     Low   Close    Volume  Adj Close
# Date
# 1984-09-07   26.50   26.87   26.25   26.50   2981600       3.02
# 1984-09-10   26.50   26.62   25.87   26.37   2346400       3.01
# 1984-09-11   26.62   27.37   26.62   26.87   5444000       3.07
# 1984-09-12   26.87   27.00   26.12   26.12   4773600       2.98
# 1984-09-13   27.50   27.62   27.50   27.50   7429600       3.14
# 1984-09-14   27.62   28.50   27.62   27.87   8826400       3.18
# 1984-09-17   28.62   29.00   28.62   28.62   6886400       3.27
# 1984-09-18   28.62   28.87   27.62   27.62   3495200       3.15
# 1984-09-19   27.62   27.87   27.00   27.00   3816000       3.08
# 1984-09-20   27.12   27.37   27.12   27.12   2387200       3.09
# 1984-09-21   27.12   27.87   26.50   26.87   3591200       3.07
# 1984-09-24   26.87   27.00   26.62   26.62   2833600       3.04
# 1984-09-25   26.50   26.50   26.12   26.12   5977600       2.98
# 1984-09-26   26.12   27.25   25.75   25.75   3987200       2.94
# ...

# %%
AAPL.index
# Out:
# DatetimeIndex(['1984-09-07', '1984-09-10', '1984-09-11', '1984-09-12',
#                '1984-09-13', '1984-09-14', '1984-09-17', '1984-09-18',
#                '1984-09-19', '1984-09-20',
#                ...
#                '2008-10-01', '2008-10-02', '2008-10-03', '2008-10-06',
#                '2008-10-07', '2008-10-08', '2008-10-09', '2008-10-10',
#                '2008-10-13', '2008-10-14'],
#               dtype='datetime64[ns]', name='Date', length=6081, freq=None)

# %%
type(AAPL.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
AAPL.shape
# Out:
# (6081, 6)

# %%
AAPL.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
AAPL.head()
# Out:
#              Open   High    Low  Close   Volume  Adj Close
# Date
# 1984-09-07  26.50  26.87  26.25  26.50  2981600       3.02
# 1984-09-10  26.50  26.62  25.87  26.37  2346400       3.01
# 1984-09-11  26.62  27.37  26.62  26.87  5444000       3.07
# 1984-09-12  26.87  27.00  26.12  26.12  4773600       2.98
# 1984-09-13  27.50  27.62  27.50  27.50  7429600       3.14

# %%
AAPL.tail()
# Out:
#               Open    High     Low   Close    Volume  Adj Close
# Date
# 2008-10-08   85.91   96.33   85.68   89.79  78847900      89.79
# 2008-10-09   93.35   95.80   86.60   88.74  57763700      88.74
# 2008-10-10   85.70  100.00   85.00   96.80  79260700      96.80
# 2008-10-13  104.55  110.53  101.02  110.26  54967000     110.26
# 2008-10-14  116.26  116.40  103.14  104.08  70749800     104.08

# %%
AAPLmore50 = AAPL[AAPL['Adj Close'] > 50].shape

# %%
AAPLmore50 = AAPL[AAPL['Adj Close'] > 50]

# %%
AAPLmore50['High'].max()
# Out:
# 202.96

# %%
AAPLmore50['High'].min()
# Out:
# 51.21

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
close = AAPL.Close
plt.plot(close)

# %%
AAPL.plot()

# %%
AAPL.isnull()
# Out:
#              Open   High    Low  Close  Volume  Adj Close
# Date
# 1984-09-07  False  False  False  False   False      False
# 1984-09-10  False  False  False  False   False      False
# 1984-09-11  False  False  False  False   False      False
# 1984-09-12  False  False  False  False   False      False
# 1984-09-13  False  False  False  False   False      False
# 1984-09-14  False  False  False  False   False      False
# 1984-09-17  False  False  False  False   False      False
# 1984-09-18  False  False  False  False   False      False
# 1984-09-19  False  False  False  False   False      False
# 1984-09-20  False  False  False  False   False      False
# 1984-09-21  False  False  False  False   False      False
# 1984-09-24  False  False  False  False   False      False
# 1984-09-25  False  False  False  False   False      False
# 1984-09-26  False  False  False  False   False      False
# 1984-09-27  False  False  False  False   False      False
# ...

# %%
AAPL.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  6081.000000  6081.000000  6081.000000  6081.000000  6.081000e+03
# mean     46.823511    47.681506    45.913595    46.798619  1.363986e+07
# std      33.993517    34.578077    33.273106    33.947235  1.352107e+07
# min      12.880000    13.190000    12.720000    12.940000  8.880000e+04
# 25%      24.730000    25.010000    24.200000    24.690000  5.530000e+06
# 50%      38.250000    38.880000    37.460000    38.130000  8.976400e+06
# 75%      53.500000    54.550000    52.500000    53.610000  1.631920e+07
# max     200.590000   202.960000   197.800000   199.830000  2.650690e+08
#
#          Adj Close
# count  6081.000000
# mean     23.529794
# std      37.375601
# min       1.650000
# 25%       7.380000
# 50%       9.910000
# 75%      14.360000
# max     199.830000

# %%
# Out:
# pandas.core.frame.DataFrame
